# %%
#Setting up any and all dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import json
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')

#Read Hulu file
hulu_df = pd.read_csv("HuluRaw.csv")
hulu_df.head()

#Read Netflix file 
netflix_df = pd.read_csv("netflix_titles.csv")
netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...

# %%
#Check out how many TV shows are in this file
num_of_types = netflix_df["type"].value_counts()
num_of_types
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
#Grab only TV shows
netflix_tv_df = netflix_df.loc[netflix_df["type"] == "TV Show"]
netflix_tv_df.head()
# Out:
#      show_id     type                             title director  \
# 2   70234439  TV Show                Transformers Prime      NaN
# 3   80058654  TV Show  Transformers: Robots in Disguise      NaN
# 5   80163890  TV Show                           Apaches      NaN
# 8   80117902  TV Show                      Fire Chasers      NaN
# 26  80244601  TV Show                   Castle of Stars      NaN
#
#                                                  cast        country  \
# 2   Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# 3   Will Friedle, Darren Criss, Constance Zimmer, ...  United States
# 5   Alberto Ammann, Eloy Azorín, Verónica Echegui,...          Spain
# 8                                                 NaN  United States
# 26  Chaiyapol Pupart, Jintanutda Lummakanon, Worra...            NaN
#
#            date_added  release_year    rating  duration  \
# 2   September 8, 2018          2013  TV-Y7-FV  1 Season
# 3   September 8, 2018          2016     TV-Y7  1 Season
# 5   September 8, 2017          2016     TV-MA  1 Season
# 8   September 8, 2017          2017     TV-MA  1 Season
# 26  September 7, 2018          2015     TV-14  1 Season
#
#                                             listed_in  \
# 2                                            Kids' TV
# 3                                            Kids' TV
# 5   Crime TV Shows, International TV Shows, Spanis...
# 8                     Docuseries, Science & Nature TV
# 26  International TV Shows, Romantic TV Shows, TV ...
#
#                                           description
# 2   With the help of three human allies, the Autob...
# 3   When a prison ship crash unleashes hundreds of...
# 5   A young journalist is forced into a life of cr...
# 8   As California's 2016 fire season rages, brave ...
# 26  As four couples with different lifestyles go t...

# %%
#Only grab the columns we want
netflix_tv_df2 = netflix_tv_df[["show_id","title","listed_in","rating","description"]]
netflix_tv_df2.head()
# Out:
#      show_id                             title  \
# 2   70234439                Transformers Prime
# 3   80058654  Transformers: Robots in Disguise
# 5   80163890                           Apaches
# 8   80117902                      Fire Chasers
# 26  80244601                   Castle of Stars
#
#                                             listed_in    rating  \
# 2                                            Kids' TV  TV-Y7-FV
# 3                                            Kids' TV     TV-Y7
# 5   Crime TV Shows, International TV Shows, Spanis...     TV-MA
# 8                     Docuseries, Science & Nature TV     TV-MA
# 26  International TV Shows, Romantic TV Shows, TV ...     TV-14
#
#                                           description
# 2   With the help of three human allies, the Autob...
# 3   When a prison ship crash unleashes hundreds of...
# 5   A young journalist is forced into a life of cr...
# 8   As California's 2016 fire season rages, brave ...
# 26  As four couples with different lifestyles go t...

# %%
#Rename columns to match the Hulu file:
netflix_tv_df2 = netflix_tv_df2.rename(columns={"show_id":"Show ID",
                                      "title":"Show Name",
                                      "listed_in":"Genre",
                                      "rating":"TV-Rating",
                                      "description":"Description"})

netflix_tv_df2 = netflix_tv_df2.sort_values(by=["Show Name"], ascending=True)
netflix_tv_df2.head()
# Out:
#        Show ID                           Show Name  \
# 1342  80234414                         100% Hotter
# 1674  80098046                    12 Years Promise
# 6151  80117470                      13 Reasons Why
# 6152  80996791  13 Reasons Why: Beyond the Reasons
# 1058  80205593                                1983
#
#                                                   Genre TV-Rating  \
# 1342  British TV Shows, International TV Shows, Real...     TV-14
# 1674  International TV Shows, Korean TV Shows, Roman...     TV-14
# 6151            Crime TV Shows, TV Dramas, TV Mysteries     TV-MA
# 6152                         Crime TV Shows, Docuseries     TV-MA
# 1058  Crime TV Shows, International TV Shows, TV Dramas     TV-MA
#
#                                             Description
# 1342  A stylist, a hair designer and a makeup artist...
# 1674  A pregnant teen is forced by her family to lea...
# 6151  After a teenage girl's perplexing suicide, a c...
# 6152  Cast members, writers, producers and mental he...
# 1058  In this dark alt-history thriller, a naïve law...

# %%
#Add Column to signify available on Netflix
netflix_tv_df2["Available on Netflix"] = "Yes" 
netflix_tv_df2.head()
# Out:
# Rosario Tijeras    2
# Top Boy            2
# Life               2
# Tunnel             2
# Lovesick           2
# Name: Show Name, dtype: int64

# %%
# Remove the duplicate rows 
netflix_tv_df2.drop_duplicates(subset = "Show ID", keep = "last", inplace = True)
netflix_tv_df2.head()
# Out:
#        Show ID                           Show Name  \
# 1342  80234414                         100% Hotter
# 1674  80098046                    12 Years Promise
# 6151  80117470                      13 Reasons Why
# 6152  80996791  13 Reasons Why: Beyond the Reasons
# 1058  80205593                                1983
#
#                                                   Genre TV-Rating  \
# 1342  British TV Shows, International TV Shows, Real...     TV-14
# 1674  International TV Shows, Korean TV Shows, Roman...     TV-14
# 6151            Crime TV Shows, TV Dramas, TV Mysteries     TV-MA
# 6152                         Crime TV Shows, Docuseries     TV-MA
# 1058  Crime TV Shows, International TV Shows, TV Dramas     TV-MA
#
#                                             Description Available on Netflix
# 1342  A stylist, a hair designer and a makeup artist...                  Yes
# 1674  A pregnant teen is forced by her family to lea...                  Yes
# 6151  After a teenage girl's perplexing suicide, a c...                  Yes
# 6152  Cast members, writers, producers and mental he...                  Yes
# 1058  In this dark alt-history thriller, a naïve law...                  Yes

# %%
# Extract relevant columns (show ID, show name, genre, TV-rating, Description)
hulu_df_2 = ["show/id", "show/name", "show/genre", "show/show_rollups/subscriber/highest_rating", "show/description"]
hulu_df_2 = hulu_df[hulu_df_2].copy()
hulu_df_2.head()
# Out:
#    show/id                          show/name              show/genre  \
# 0       54                         Family Guy  Animation and Cartoons
# 1     6979                         South Park                  Comedy
# 2       53                      American Dad!                  Comedy
# 3      389  Law & Order: Special Victims Unit                   Drama
# 4     1603                   Naruto Shippuden                   Anime
#
#   show/show_rollups/subscriber/highest_rating  \
# 0                                       TV-MA
# 1                                       TV-MA
# 2                                       TV-14
# 3                                       TV-14
# 4                                       TV-14
#
#                                     show/description
# 0  The adventures of an endearingly ignorant dad ...
# 1  Underpants-stealing gnomes, a talking Christma...
# 2  This screwball family full of radically differ...
# 3  This hard-hitting and emotional series from NB...
# 4  The Village Hidden in the Leaves is home to th...

# %%
# Rename columns 
hulu_df_2 = hulu_df_2.rename(columns={"show/id":"Show ID", 
                                      "show/name":"Show Name",
                                      "show/genre":"Genre",
                                      "show/show_rollups/subscriber/highest_rating":"TV-Rating",
                                      "show/description":"Description"})

#Add Column to signify available on Hulu
hulu_df_2["Available on Hulu"] = "Yes"
hulu_df_2.head()
# Out:
#    Show ID                          Show Name                   Genre  \
# 0       54                         Family Guy  Animation and Cartoons
# 1     6979                         South Park                  Comedy
# 2       53                      American Dad!                  Comedy
# 3      389  Law & Order: Special Victims Unit                   Drama
# 4     1603                   Naruto Shippuden                   Anime
#
#   TV-Rating                                        Description  \
# 0     TV-MA  The adventures of an endearingly ignorant dad ...
# 1     TV-MA  Underpants-stealing gnomes, a talking Christma...
# 2     TV-14  This screwball family full of radically differ...
# 3     TV-14  This hard-hitting and emotional series from NB...
# 4     TV-14  The Village Hidden in the Leaves is home to th...
#
#   Available on Hulu
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes
# 4               Yes

# %%
# Sort shows alphabetically 
hulu_df_2 = hulu_df_2.sort_values(by=["Show Name"], ascending=True)
hulu_df_2.head()
# Out:
#      Show ID       Show Name Genre TV-Rating  \
# 700    22416  Adventure Time  Kids     TV-PG
# 106    22416  Adventure Time  Kids     TV-PG
# 502    22416  Adventure Time  Kids     TV-PG
# 601    22416  Adventure Time  Kids     TV-PG
# 205    22416  Adventure Time  Kids     TV-PG
#
#                                            Description Available on Hulu
# 700  It's one crazy adventure after another for hum...               Yes
# 106  It's one crazy adventure after another for hum...               Yes
# 502  It's one crazy adventure after another for hum...               Yes
# 601  It's one crazy adventure after another for hum...               Yes
# 205  It's one crazy adventure after another for hum...               Yes

# %%
# Assess duplicates 
num_of_shows = hulu_df_2["Show Name"].value_counts()
num_of_shows
# Out:
# The Cleveland Show    10
# Sleepy Hollow         10
# The Voice             10
# Once Upon a Time      10
# Project Runway        10
# Name: Show Name, dtype: int64

# %%
# Remove the duplicate rows 
hulu_df_2.drop_duplicates(subset = "Show ID", keep = "last", inplace = True)
hulu_df_2.head()
# Out:
#      Show ID                 Show Name                   Genre TV-Rating  \
# 403    22416            Adventure Time                    Kids     TV-PG
# 51       969      America's Got Talent  Reality and Game Shows     TV-PG
# 42      8322  America's Next Top Model  Reality and Game Shows     TV-14
# 200       53             American Dad!                  Comedy     TV-14
# 931     3433                    Archer  Animation and Cartoons     TV-MA
#
#                                            Description Available on Hulu
# 403  It's one crazy adventure after another for hum...               Yes
# 51   America votes in the ultimate talent show to d...               Yes
# 42   Young women of various backgrounds, shapes and...               Yes
# 200  This screwball family full of radically differ...               Yes
# 931  Archer chronicles an international spy agency ...               Yes

# %%
# Confirm duplicates were removed 
num_of_shows2 = hulu_df_2["Show Name"].value_counts()
num_of_shows2.head()
# Out:
# The Cleveland Show    1
# Grey's Anatomy        1
# The Goldbergs         1
# Brooklyn Nine-Nine    1
# The Mindy Project     1
# Name: Show Name, dtype: int64

# %%
#109 tv shows for hulu, 1969 for Netflix
#Merge two dataframes together
df = pd.concat([netflix_tv_df2, hulu_df_2],ignore_index=True)

df = df[['Show ID','Show Name','Genre','TV-Rating', 'Description', 'Available on Hulu', 'Available on Netflix']]
df.head()
# Out:
#     Show ID                           Show Name  \
# 0  80234414                         100% Hotter
# 1  80098046                    12 Years Promise
# 2  80117470                      13 Reasons Why
# 3  80996791  13 Reasons Why: Beyond the Reasons
# 4  80205593                                1983
#
#                                                Genre TV-Rating  \
# 0  British TV Shows, International TV Shows, Real...     TV-14
# 1  International TV Shows, Korean TV Shows, Roman...     TV-14
# 2            Crime TV Shows, TV Dramas, TV Mysteries     TV-MA
# 3                         Crime TV Shows, Docuseries     TV-MA
# 4  Crime TV Shows, International TV Shows, TV Dramas     TV-MA
#
#                                          Description Available on Hulu  \
# 0  A stylist, a hair designer and a makeup artist...               NaN
# 1  A pregnant teen is forced by her family to lea...               NaN
# 2  After a teenage girl's perplexing suicide, a c...               NaN
# 3  Cast members, writers, producers and mental he...               NaN
# 4  In this dark alt-history thriller, a naïve law...               NaN
#
#   Available on Netflix
# 0                  Yes
# 1                  Yes
# 2                  Yes
# 3                  Yes
# 4                  Yes

# %%
#Make all NaN's to No
df.fillna("No", inplace=True)
df.head()
# Out:
#     Show ID                           Show Name  \
# 0  80234414                         100% Hotter
# 1  80098046                    12 Years Promise
# 2  80117470                      13 Reasons Why
# 3  80996791  13 Reasons Why: Beyond the Reasons
# 4  80205593                                1983
#
#                                                Genre TV-Rating  \
# 0  British TV Shows, International TV Shows, Real...     TV-14
# 1  International TV Shows, Korean TV Shows, Roman...     TV-14
# 2            Crime TV Shows, TV Dramas, TV Mysteries     TV-MA
# 3                         Crime TV Shows, Docuseries     TV-MA
# 4  Crime TV Shows, International TV Shows, TV Dramas     TV-MA
#
#                                          Description Available on Hulu  \
# 0  A stylist, a hair designer and a makeup artist...                No
# 1  A pregnant teen is forced by her family to lea...                No
# 2  After a teenage girl's perplexing suicide, a c...                No
# 3  Cast members, writers, producers and mental he...                No
# 4  In this dark alt-history thriller, a naïve law...                No
#
#   Available on Netflix
# 0                  Yes
# 1                  Yes
# 2                  Yes
# 3                  Yes
# 4                  Yes

# %%
#Convert & Save as csv file
df.to_csv("netflix_hulu_tvshows.csv")
